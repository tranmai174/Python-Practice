# %% [markdown]
# # Python Project 2:
#
# US Cars'dataset
#
# US Cars'data was scraped from AUCTION EXPORT.com. This dataset included Information about 28 brands of clean and used vehicles for sale in US. Twelve features were assembled for each car in the dataset.
#
# This dataset includes 12 features: Price, Year, Brand, Model, Color, State/City, Mileage, Vin, Title Status, Lot, Condition

# %%
import pandas as pd

# %%
cars = pd.read_csv(r'/Users/tranngocmai/Documents/DATA SCIENCE/python/project/USA_cars_datasets.csv')

# %%
cars
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1              1   2899       ford       se  2011  clean vehicle  190552.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3              3  25000       ford     door  2014  clean vehicle   64146.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6654.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23609.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34553.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31594.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32557.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31371.0
#
#        color                  vin        lot       state country  \
# ...

# %%
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
cars.shape
# Out:
# (2499, 13)

# %%
cars.index
# Out:
# RangeIndex(start=0, stop=2499, step=1)

# %%
cars.columns
# Out:
# Index(['Unnamed: 0', 'price', 'brand', 'model', 'year', 'title_status',
#        'mileage', 'color', 'vin', 'lot', 'state', 'country', 'condition'],
#       dtype='object')

# %%
cars.dtypes
# Out:
# Unnamed: 0        int64
# price             int64
# brand            object
# model            object
# year              int64
# title_status     object
# mileage         float64
# color            object
# vin              object
# lot               int64
# state            object
# country          object
# condition        object
# dtype: object

# %% [markdown]
# 1) Instruction (For Data Cleaning)
# #Find all null value in the dataset. If there is any null value in any column, then fill it with the mean of that column

# %%
cars.isnull()
# Out:
#       Unnamed: 0  price  brand  model   year  title_status  mileage  color  \
# 0          False  False  False  False  False         False    False  False
# 1          False  False  False  False  False         False    False  False
# 2          False  False  False  False  False         False    False  False
# 3          False  False  False  False  False         False    False  False
# 4          False  False  False  False  False         False    False  False
# ...          ...    ...    ...    ...    ...           ...      ...    ...
# 2494       False  False  False  False  False         False    False  False
# 2495       False  False  False  False  False         False    False  False
# 2496       False  False  False  False  False         False    False  False
# 2497       False  False  False  False  False         False    False  False
# 2498       False  False  False  False  False         False    False  False
#
#         vin    lot  state  country  condition
# ...

# %%
cars.isnull().sum()
# Out:
# Unnamed: 0      0
# price           0
# brand           0
# model           0
# year            0
# title_status    0
# mileage         0
# color           0
# vin             0
# lot             0
# state           0
# country         0
# condition       0
# dtype: int64

# %% [markdown]
# If there are null values. Write cars['columns with null value'].fillna(cars['columns with null value'].means(), inplace = True)

# %% [markdown]
# 2) Question (Based on Value Counts)
# #Check what are the different types of Brand are there in the dataset. And, what is the count (occurence) of each Brand in the data?

# %%
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
cars['brand'].value_counts()
# Out:
# ford               1235
# dodge               432
# nissan              312
# chevrolet           297
# gmc                  42
# jeep                 30
# chrysler             18
# bmw                  17
# hyundai              15
# kia                  13
# buick                13
# infiniti             12
# honda                12
# mercedes-benz        10
# cadillac             10
# heartland             5
# land                  4
# peterbilt             4
# audi                  4
# acura                 3
# lexus                 2
# mazda                 2
# lincoln               2
# toyota                1
# harley-davidson       1
# jaguar                1
# maserati              1
# ram                   1
# Name: brand, dtype: int64

# %% [markdown]
# 3) Instruction (Filtering)
# #Show all the records where State is California or Texas (most populated state)

# %%
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %% [markdown]
# isin(): Whether each element in the DataFrame is contained in values.

# %%
cars[cars['state'].isin(['california','texas'])]
# Out:
#       Unnamed: 0  price     brand   model  year   title_status   mileage  \
# 5              5   5700     dodge     mpv  2018  clean vehicle   45561.0
# 7              7  13350       gmc    door  2017  clean vehicle   23525.0
# 9              9   5250      ford     mpv  2017  clean vehicle   63418.0
# 11            11  12920       gmc     mpv  2017  clean vehicle   39650.0
# 13            13   5430  chrysler   wagon  2017  clean vehicle  138650.0
# ...          ...    ...       ...     ...   ...            ...       ...
# 2486        2486   9500    nissan  sentra  2019  clean vehicle   19646.0
# 2488        2488   1700    nissan    note  2019  clean vehicle   33279.0
# 2490        2490  10400    nissan  sentra  2019  clean vehicle   25264.0
# 2492        2492   7400    nissan   versa  2019  clean vehicle   35511.0
# 2494        2494   7800    nissan   versa  2019  clean vehicle   23609.0
#
#       color                  vin        lot       state country      condition
# ...

# %% [markdown]
# tolist(): Return a list of the values.

# %%
cars['year'].tolist()
# Out:
# [2008,
#  2011,
#  2018,
#  2014,
#  2018,
#  2018,
#  2010,
#  2017,
#  2018,
#  2017,
#  2009,
#  2017,
#  2018,
#  2017,
#  2013,
#  2017,
#  2018,
#  2018,
#  2017,
#  2013,
#  2017,
#  2018,
#  2015,
#  2017,
#  2013,
#  2017,
#  2020,
#  2014,
#  2017,
#  2008,
#  2017,
#  2016,
#  1973,
#  2017,
#  2003,
#  2017,
#  2016,
#  2018,
#  2017,
#  2003,
#  2017,
#  2016,
#  2018,
#  2017,
#  2017,
#  2017,
#  2019,
#  2017,
#  2017,
#  2017,
#  2017,
#  2019,
#  2017,
#  2017,
#  2019,
#  2017,
#  2019,
#  2017,
#  2020,
#  2019,
#  2017,
#  2019,
#  2017,
#  2017,
#  2019,
#  2017,
#  2019,
#  2017,
#  2017,
#  2019,
#  2017,
#  2019,
#  2017,
#  2017,
#  2019,
#  2017,
#  2019,
#  2017,
#  2017,
#  2019,
#  2017,
#  2019,
#  2017,
#  2017,
#  2016,
#  2017,
#  2019,
#  2017,
#  2017,
#  2016,
#  2017,
#  2015,
#  2017,
#  2017,
#  2015,
#  2017,
#  2017,
#  2015,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2018,
#  2017,
#  2017,
#  2018,
#  2017,
# ...

# %%
cars['price'].tolist()
# Out:
# [6300,
#  2899,
#  5350,
#  25000,
#  27700,
#  5700,
#  7300,
#  13350,
#  14600,
#  5250,
#  10400,
#  12920,
#  31900,
#  5430,
#  20700,
#  12710,
#  5200,
#  16500,
#  5210,
#  38100,
#  12520,
#  7300,
#  15000,
#  6180,
#  20800,
#  11900,
#  21500,
#  12000,
#  4190,
#  13000,
#  12710,
#  18500,
#  29800,
#  5330,
#  13000,
#  11900,
#  16600,
#  19200,
#  7320,
#  7000,
#  12710,
#  16600,
#  30500,
#  6330,
#  55000,
#  12520,
#  16200,
#  19000,
#  5580,
#  54000,
#  12710,
#  16000,
#  27000,
#  7760,
#  19600,
#  12920,
#  20000,
#  18100,
#  23000,
#  18500,
#  13490,
#  20700,
#  17800,
#  6650,
#  29100,
#  12710,
#  21100,
#  18600,
#  4340,
#  19300,
#  12780,
#  15800,
#  29400,
#  4430,
#  19400,
#  12520,
#  15900,
#  26400,
#  4140,
#  18300,
#  12520,
#  17900,
#  18300,
#  4640,
#  24000,
#  13200,
#  18000,
#  14900,
#  4140,
#  11500,
#  9110,
#  7350,
#  24500,
#  9300,
#  39800,
#  53500,
#  15110,
#  34000,
#  26502,
#  5990,
#  13600,
#  23605,
# ...

# %% [markdown]
# 4) Instruction (Removing unwanted records)
# #Remove all the records (rows) where price = 0

# %%
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
cars[cars.price == 0]
# Out:
#      Unnamed: 0  price      brand     model  year       title_status  \
# 141         141      0      dodge       van  2008  salvage insurance
# 144         144      0      dodge      door  2014  salvage insurance
# 196         196      0       ford       mpv  2017      clean vehicle
# 285         285      0       ford      door  2000  salvage insurance
# 290         290      0      mazda      door  2009  salvage insurance
# 293         293      0  chevrolet    pickup  1998  salvage insurance
# 297         297      0      honda      door  2003  salvage insurance
# 305         305      0       ford      door  2003  salvage insurance
# 309         309      0  chevrolet      door  2004  salvage insurance
# 310         310      0  chevrolet      door  2003  salvage insurance
# 313         313      0       ford       van  1998  salvage insurance
# 314         314      0       ford      door  2013  salvage insurance
# 318         318      0  chevrolet      door  2009  salvage insurance
# ...

# %%
cars.shape
# Out:
# (2499, 13)

# %%
cars.groupby([cars.price == 0]).count()
# Out:
#        Unnamed: 0  price  brand  model  year  title_status  mileage  color  \
# price
# False        2456   2456   2456   2456  2456          2456     2456   2456
# True           43     43     43     43    43            43       43     43
#
#         vin   lot  state  country  condition
# price
# False  2456  2456   2456     2456       2456
# True     43    43     43       43         43

# %%
2499-43
# Out:
# 2456

# %%
cars = cars[cars.price != 0]

# %%
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %%
cars.shape
# Out:
# (2456, 13)

# %% [markdown]
# 5) Instruction (Applying function on a column)
# #Increase all the values of 'mileage' column by 1

# %%
cars.head()
# Out:
#    Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0           0   6300     toyota  cruiser  2008  clean vehicle  274117.0
# 1           1   2899       ford       se  2011  clean vehicle  190552.0
# 2           2   5350      dodge      mpv  2018  clean vehicle   39590.0
# 3           3  25000       ford     door  2014  clean vehicle   64146.0
# 4           4  27700  chevrolet     1500  2018  clean vehicle    6654.0
#
#     color                  vin        lot       state country      condition
# 0   black    jtezu11f88k007763  159348797  new jersey     usa   10 days left
# 1  silver    2fmdk3gc4bbb02217  166951262   tennessee     usa    6 days left
# 2  silver    3c4pdcgg5jt346413  167655728     georgia     usa    2 days left
# 3    blue    1ftfw1et4efc23745  167753855    virginia     usa  22 hours left
# 4     red    3gcpcrec2jg473991  167763266     florida     usa  22 hours left

# %% [markdown]
# USE pandas.DataFrame.apply() TO MODIFY ALL THE VALUES IN A COLUMN.
# Alternatively, use a lambda function for func with the syntax lambda x: expression to apply expression to each value in the column.

# %%
cars.mileage = cars.mileage.apply(lambda x: x + 1)

# %%
cars
# Out:
#       Unnamed: 0  price      brand    model  year   title_status   mileage  \
# 0              0   6300     toyota  cruiser  2008  clean vehicle  274122.0
# 1              1   2899       ford       se  2011  clean vehicle  190557.0
# 2              2   5350      dodge      mpv  2018  clean vehicle   39595.0
# 3              3  25000       ford     door  2014  clean vehicle   64151.0
# 4              4  27700  chevrolet     1500  2018  clean vehicle    6659.0
# ...          ...    ...        ...      ...   ...            ...       ...
# 2494        2494   7800     nissan    versa  2019  clean vehicle   23614.0
# 2495        2495   9200     nissan    versa  2018  clean vehicle   34558.0
# 2496        2496   9200     nissan    versa  2018  clean vehicle   31599.0
# 2497        2497   9200     nissan    versa  2018  clean vehicle   32562.0
# 2498        2498   9200     nissan    versa  2018  clean vehicle   31376.0
#
#        color                  vin        lot       state country  \
# ...
